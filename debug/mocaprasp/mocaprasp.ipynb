# %% [markdown]
# # MoCap Rasp Arena
#
# This notebook is an implementation of the MoCap Rasp Optical Tracking Arena.
#
# ---

# %%
# Importing modules...
import numpy as np
import socket
import time

import sys
sys.path.append('../..') # Go back to base directory

from modules.plot.viewer3d import Viewer3D

from modules.vision.camera import Camera
from modules.vision.synchronizer import Synchronizer

from modules.integration.client import Client
from modules.integration.mocaprasp.server import MoCapRasp_Server

from intrinsic import * # Intrinsic Calibration data

# %% [markdown]
# # Setting Up
#
# All `Camera` and `Client` objects will be instanciated right along with the `Server` object.
#
# ---

# %%
n_clients = 4 # Number of clients in the arena
clients = []  # Clients list

# Create clients
for K, D in zip(intrinsic_matrices, distortion_coefficients):
    # Generate associated camera model
    camera = (Camera(# Intrinsic Parameters
                     resolution=(960, 720),
                     intrinsic_matrix=K.copy(),
 
                     # Fisheye Lens Distortion Model
                     distortion_model='fisheye',
                     distortion_coefficients=D.copy()
                     ))
    
    clients.append(Client(camera=camera))

# Create server
server = MoCapRasp_Server(clients=clients,
                          server_address=('0.0.0.0', 8888))

# Register clients
server.register_clients()
# Out:
# [SERVER] Wrapping up CoppeliaSim scene info
# [SERVER] Scene info sent
# [SERVER] Scene set!

# %% [markdown]
# # Extrinsic Calibration
#
# The Cameras' Extrinsic Parameters will be estimated. For that, a calibration routine will be requested and the data will be post-processed for the parameter estimation.
#
# ---

# %%
input('Press Enter key to start Extrinsic Calibration...')

# %%
# Capture specifications
blob_count = 3 # Number of expected markers
delay_time = 10.0 # In seconds
capture_time = 30.0 # In seconds
window = 3 # The minimum ammount of points for interpolating 
throughput = 20 # Triangulated scenes per second
step = 1 / throughput # Interpolation timestep

# Capture synchronizer
synchronizer = Synchronizer(blob_count, window, step, capture_time)

# Request capture (start simulation)
if not server.request_capture(delay_time, synchronizer):
    sys.exit() # Capture request failed!

# %%
verbose = False

print('[SERVER] Waiting delay...')
time.sleep(delay_time)

timeout = 5 # In seconds
server.udp_socket.settimeout(timeout) # Set server timeout
print(f'[SERVER] Timeout set to {timeout} seconds\n')

# Receiving messages
while True: 
    # Wait for message - Event guided!
    try:
        message_bytes, address = server.udp_socket.recvfrom(server.buffer_size)

    except socket.timeout as err:
        print('\n[SERVER] Timed Out!')
        
        break # Close capture loop due to timeout
    
    # Check if client exists
    try:
        ID = server.client_addresses[address] # Client Identifier
    
    except:
        if verbose: print('> Client not recognized')

        continue # Jump to wait for the next message
    
    # Show sender
    if verbose: print(f'> Received message from Client {ID} ({address[0]}, {address[1]})')

    # Save message
    server.clients[ID].message_log.append(message_bytes)

# Post-processing
for client in server.clients:
    # Parse through client's message history
    for message_bytes in client.message_log: 

        # Decode message
        try:
            message = np.frombuffer(message_bytes, dtype=np.float32)

        except:
            if verbose: print('> Couldn\'t decode message')

            continue # Jump to the next message

        # Empty message
        if not message.size:
            if verbose: print('\tEmpty message')

            continue # Jump to the next message
        
        # The message is composed as:
        # [u, v, A] (for each blob detected) + [u_min, y_min, PTS, IID] 
        IID = message[-1] # Image Index
        PTS = message[-2] # Presentation Timestamp
        
        # Valid message must have (3 * blob_count + 4) total elements
        if message.size !=  3 * blob_count + 4: 
            if message.size == 4: 
                if verbose: print(f'\tNo blobs were detected - {PTS :.3f} s')

            else: 
                if verbose: 
                    print(f'\tWrong blob count or corrupted message')
                    print(f'Corrupted Message: {message}')

            continue # Jump to the next message

        # Extracting blob data (coordinates & area)
        blob_data = message[:-4].reshape(-1, 3) # All but last 4 elements

        # Extracting centroids
        blob_centroids = blob_data[:,:2] # Ignoring their area

        # Undistorting blobs centroids
        undistorted_blobs = client.camera.undistort_points(blob_centroids)          

        # Print blobs
        if verbose:
            print(f'\tDetected Blobs - {PTS :.3f} s')
            print('\t' + str(blob_data).replace('\n', '\n\t'))

        # Save data
        valid_data = client.synchronizer.add_data(undistorted_blobs, PTS)

        if verbose: 
            if valid_data:
                print('\tData Accepted!')
            else:
                print('\tData Refused!')
# Out:
# [SERVER] Extrinsic Calibration info sent
# [SERVER] Extrinsic Calibration confirmed!
# [SERVER] Waiting for clients...
# 	Client 0 registered
# 	Client 1 registered
# 	Client 2 registered
# 	Client 3 registered
# [SERVER] All clients registered!
# [SERVER] Timeout set to 5 seconds
#
#
# [SERVER] Timed Out!

# %%
# Calibrate multiple view
wand_distances = np.array([5e-2, 10e-2, 15e-2]) # In meters

wand_blobs = [client.synchronizer.sync_blobs for client in server.clients]

if not server.multiple_view.calibrate(wand_blobs, wand_distances):
    sys.exit() # Calibration failed!

# %%
# Create the Scene Viewer
scene = Viewer3D(title='Calibrated Camera Poses', 
                 size=10)

# Add camera frames to the scene
for ID, camera in enumerate(server.multiple_view.camera_models): 
    scene.add_frame(camera.pose, f'Camera {ID}', axis_size=0.4)

# Plot scene
scene.figure.show(renderer='notebook_connected')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="44cbb2fc-3b81-4c08-af4f-9c2247b93c0f" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44cbb2fc-3b81-4c08-af4f-9c2247b93c0f")) {                    Plotly.newPlot(                        "44cbb2fc-3b81-4c08-af4f-9c2247b93c0f",                        [{"legendgroup":"Frames","legendgrouptitle":{"text":"Frames"},"marker":{"opacity":0.8,"size":4},"mode":"markers","name":"Camera 0","showlegend":true,"x":[0.0],"y":[0.0],"z":[0.0],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"red","width":2},"mode":"lines","name":"xCamera 0","showlegend":false,"x":[0.0,0.4],"y":[0.0,0.0],"z":[0.0,0.0],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"green","width":2},"mode":"lines","name":"yCamera 0","showlegend":false,"x":[0.0,0.0],"y":[0.0,0.4],"z":[0.0,0.0],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"blue","width":2},"mode":"lines","name":"zCamera 0","showlegend":false,"x":[0.0,0.0],"y":[0.0,0.0],"z":[0.0,0.4],"type":"scatter3d"},{"legendgroup":"Frames","legendgrouptitle":{"text":"Frames"},"marker":{"opacity":0.8,"size":4},"mode":"markers","name":"Camera 1","showlegend":true,"x":[3.5986795409733277],"y":[-2.5150083543070347],"z":[2.4165799121600697],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"red","width":2},"mode":"lines","name":"xCamera 1","showlegend":false,"x":[3.5986795409733277,3.5959178963610237],"y":[-2.5150083543070347,-2.7992067378782073],"z":[2.4165799121600697,2.6980468766418153],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"green","width":2},"mode":"lines","name":"yCamera 1","showlegend":false,"x":[3.5986795409733277,3.8778044629262647],"y":[-2.5150083543070347,-2.314768035042047],"z":[2.4165799121600697,2.62150207417634],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"blue","width":2},"mode":"lines","name":"zCamera 1","showlegend":false,"x":[3.5986795409733277,3.3121805858900637],"y":[-2.5150083543070347,-2.3171824376121064],"z":[2.4165799121600697,2.6135145597465455],"type":"scatter3d"},{"legendgroup":"Frames","legendgrouptitle":{"text":"Frames"},"marker":{"opacity":0.8,"size":4},"mode":"markers","name":"Camera 2","showlegend":true,"x":[-0.015122693925902233],"y":[-5.02448590828461],"z":[4.986443795755947],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"red","width":2},"mode":"lines","name":"xCamera 2","showlegend":false,"x":[-0.015122693925902233,-0.4151207522916934],"y":[-5.02448590828461,-5.023508564806531],"z":[4.986443795755947,4.987217167156416],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"green","width":2},"mode":"lines","name":"yCamera 2","showlegend":false,"x":[-0.015122693925902233,-0.014350417142456532],"y":[-5.02448590828461,-5.0249346502789445],"z":[4.986443795755947,5.3864427985286945],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"blue","width":2},"mode":"lines","name":"zCamera 2","showlegend":false,"x":[-0.015122693925902233,-0.01414448527384621],"y":[-5.02448590828461,-4.624487353999287],"z":[4.986443795755947,4.986890648622856],"type":"scatter3d"},{"legendgroup":"Frames","legendgrouptitle":{"text":"Frames"},"marker":{"opacity":0.8,"size":4},"mode":"markers","name":"Camera 3","showlegend":true,"x":[-3.499042076719804],"y":[-2.4954511942941773],"z":[2.5757190422719094],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"red","width":2},"mode":"lines","name":"xCamera 3","showlegend":false,"x":[-3.499042076719804,-3.499887460741622],"y":[-2.4954511942941773,-2.2126969478398486],"z":[2.5757190422719094,2.292789154423523],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"green","width":2},"mode":"lines","name":"yCamera 3","showlegend":false,"x":[-3.499042076719804,-3.7810831079937817],"y":[-2.4954511942941773,-2.2952454647087572],"z":[2.5 ...

# %%
# Perform bundle adjustment
n_observations = 72
server.multiple_view.bundle_adjustment(wand_blobs, wand_distances, n_observations)

# %%
# Create the Scene Viewer
scene = Viewer3D(title='Adjusted Camera Poses', 
                 size=10)

# Add camera frames to the scene
for ID, camera in enumerate(server.multiple_view.camera_models): 
    scene.add_frame(camera.pose, f'Camera {ID}', axis_size=0.4)

# Plot scene
scene.figure.show(renderer='notebook_connected')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="065c3d2e-8c84-4bfa-9bd4-d299d7c54822" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("065c3d2e-8c84-4bfa-9bd4-d299d7c54822")) {                    Plotly.newPlot(                        "065c3d2e-8c84-4bfa-9bd4-d299d7c54822",                        [{"legendgroup":"Frames","legendgrouptitle":{"text":"Frames"},"marker":{"opacity":0.8,"size":4},"mode":"markers","name":"Camera 0","showlegend":true,"x":[0.025164358755132683],"y":[-0.052971853732839594],"z":[-0.03001795407883963],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"red","width":2},"mode":"lines","name":"xCamera 0","showlegend":false,"x":[0.025164358755132683,0.42514489621261786],"y":[-0.052971853732839594,-0.05352668720162773],"z":[-0.03001795407883963,-0.026111316772502093],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"green","width":2},"mode":"lines","name":"yCamera 0","showlegend":false,"x":[0.025164358755132683,0.02576403008113831],"y":[-0.052971853732839594,0.3470013405265112],"z":[-0.03001795407883963,-0.03460971499078448],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"blue","width":2},"mode":"lines","name":"zCamera 0","showlegend":false,"x":[0.025164358755132683,0.021264352406147807],"y":[-0.052971853732839594,-0.04837445949331537],"z":[-0.03001795407883963,0.36993661073657075],"type":"scatter3d"},{"legendgroup":"Frames","legendgrouptitle":{"text":"Frames"},"marker":{"opacity":0.8,"size":4},"mode":"markers","name":"Camera 1","showlegend":true,"x":[3.522366275102185],"y":[-2.5329988584237233],"z":[2.513698194361791],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"red","width":2},"mode":"lines","name":"xCamera 1","showlegend":false,"x":[3.522366275102185,3.5196424125278947],"y":[-2.5329988584237233,-2.813630717768599],"z":[2.513698194361791,2.798721597073418],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"green","width":2},"mode":"lines","name":"yCamera 1","showlegend":false,"x":[3.522366275102185,3.8050060839363686],"y":[-2.5329988584237233,-2.3326627662514023],"z":[2.513698194361791,2.7136486598158616],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"blue","width":2},"mode":"lines","name":"zCamera 1","showlegend":false,"x":[3.522366275102185,3.239333911166799],"y":[-2.5329988584237233,-2.330239864310611],"z":[2.513698194361791,2.7106283120974646],"type":"scatter3d"},{"legendgroup":"Frames","legendgrouptitle":{"text":"Frames"},"marker":{"opacity":0.8,"size":4},"mode":"markers","name":"Camera 2","showlegend":true,"x":[-0.0451190918940948],"y":[-4.996397033605467],"z":[5.0173544151528775],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"red","width":2},"mode":"lines","name":"xCamera 2","showlegend":false,"x":[-0.0451190918940948,-0.44510230842800924],"y":[-4.996397033605467,-4.994727053879111],"z":[5.0173544151528775,5.014092872742101],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"green","width":2},"mode":"lines","name":"yCamera 2","showlegend":false,"x":[-0.0451190918940948,-0.048365541252193056],"y":[-4.996397033605467,-4.992806465908529],"z":[5.0173544151528775,5.417325124568178],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"blue","width":2},"mode":"lines","name":"zCamera 2","showlegend":false,"x":[-0.0451190918940948,-0.0434199574823901],"y":[-4.996397033605467,-4.596416635346593],"z":[5.0173544151528775,5.013777551872895],"type":"scatter3d"},{"legendgroup":"Frames","legendgrouptitle":{"text":"Frames"},"marker":{"opacity":0.8,"size":4},"mode":"markers","name":"Camera 3","showlegend":true,"x":[-3.542347028836897],"y":[-2.521969239223561],"z":[2.484472483944516],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"red","width":2},"mode":"lines","name":"xCamera 3","showlegend":false,"x":[-3.54234702 ...

# %% [markdown]
# # Reference Update
#
# Right after the Extrinsic Calibration, a new reference will be set to be the new scene's canonical frame. For that, a new reference will be requested.
#
# ---

# %%
input('Press Enter key to start Reference Update...')

# %%
# Capture specifications
blob_count = 3 # Number of expected markers
delay_time = 1.0 # In seconds
capture_time = 1.0 # In seconds
window = 3 # The minimum ammount of points for interpolating 
throughput = 20 # Triangulated scenes per second
step = 1 / throughput # Interpolation timestep

# Capture synchronizer
synchronizer = Synchronizer(blob_count, window, step, capture_time)

# Request capture (start simulation)
if not server.request_capture(delay_time, synchronizer):
    sys.exit() # Capture request failed!

# %%
verbose = False

print('[SERVER] Waiting delay...')
time.sleep(delay_time)

timeout = 5 # In seconds
server.udp_socket.settimeout(timeout) # Set server timeout
print(f'[SERVER] Timeout set to {timeout} seconds\n')

# Breaks in the timeout
while True: 
    # Wait for message - Event guided!
    try:
        message_bytes, address = server.udp_socket.recvfrom(server.buffer_size)

    except socket.timeout as err:
        print('\n[SERVER] Timed Out!')
        
        break # Close capture loop due to timeout
    
    # Check if client exists
    try:
        ID = server.client_addresses[address] # Client Identifier
    
    except:
        if verbose: print('> Client not recognized')

        continue # Jump to wait for the next message
    
    # Show sender
    if verbose: print(f'> Received message from Client {ID} ({address[0]}, {address[1]})')

    # Save message
    server.clients[ID].message_log.append(message_bytes)

# Post-processing
for client in server.clients:
    # Parse through client's message history
    for message_bytes in client.message_log: 

        # Decode message
        try:
            message = np.frombuffer(message_bytes, dtype=np.float32)

        except:
            if verbose: print('> Couldn\'t decode message')

            continue # Jump to the next message

        # Empty message
        if not message.size:
            if verbose: print('\tEmpty message')

            continue # Jump to the next message
        
        # The message is composed as:
        # [u, v, A] (for each blob detected) + [u_min, y_min, PTS, IID] 
        IID = message[-1] # Image Index
        PTS = message[-2] # Presentation Timestamp
        
        # Valid message must have (3 * blob_count + 4) total elements
        if message.size !=  3 * blob_count + 4: 
            if message.size == 4: 
                if verbose: print(f'\tNo blobs were detected - {PTS :.3f} s')

            else: 
                if verbose: 
                    print(f'\tWrong blob count or corrupted message')
                    print(f'Corrupted Message: {message}')

            continue # Jump to the next message

        # Extracting blob data (coordinates & area)
        blob_data = message[:-4].reshape(-1, 3) # All but last 4 elements

        # Extracting centroids
        blob_centroids = blob_data[:,:2] # Ignoring their area

        # Undistorting blobs centroids
        undistorted_blobs = client.camera.undistort_points(blob_centroids)          

        # Print blobs
        if verbose:
            print(f'\tDetected Blobs - {PTS :.3f} s')
            print('\t' + str(blob_data).replace('\n', '\n\t'))

        # Save data
        valid_data = client.synchronizer.add_data(undistorted_blobs, PTS)

        if verbose: 
            if valid_data:
                print('\tData Accepted!')
            else:
                print('\tData Refused!')
# Out:
# [SERVER] Reference Update info sent
# [SERVER] Reference Update confirmed!
# [SERVER] Waiting for clients...
# 	Client 0 registered
# 	Client 1 registered
# 	Client 2 registered
# 	Client 3 registered
# [SERVER] All clients registered!
# [SERVER] Timeout set to 5 seconds
#
#
# [SERVER] Timed Out!

# %%
# Measured distances between perpendicularly matched marker distances
# Distances: [D_x, D_y]
wand_distances = np.array([20e-2, 10e-2]) # In meters

# Triangulation pair
pair = (0, 2) # Diagonal pairs seems to produce more stable results

wand_blobs = [server.clients[ID].synchronizer.async_blobs for ID in pair]

# Update reference
server.multiple_view.update_reference(wand_blobs, wand_distances, pair)

# %%
# Create the Scene Viewer
scene = Viewer3D(title='Updated Camera Poses', 
                 size=10)

# Add camera frames to the scene
for ID, camera in enumerate(server.multiple_view.camera_models): 
    scene.add_frame(camera.pose, f'Camera {ID}', axis_size=0.4)

# Add new reference
scene.add_frame(np.eye(4), 'Reference', axis_size=0.4)

# Plot scene
scene.figure.show(renderer='notebook_connected')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="f7773e1c-03ba-447c-a1ab-63cd4fa78cbb" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7773e1c-03ba-447c-a1ab-63cd4fa78cbb")) {                    Plotly.newPlot(                        "f7773e1c-03ba-447c-a1ab-63cd4fa78cbb",                        [{"legendgroup":"Frames","legendgrouptitle":{"text":"Frames"},"marker":{"opacity":0.8,"size":4},"mode":"markers","name":"Camera 0","showlegend":true,"x":[2.483671569877341],"y":[2.502964870068823],"z":[2.5151894616807247],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"red","width":2},"mode":"lines","name":"xCamera 0","showlegend":false,"x":[2.483671569877341,2.1991376615535048],"y":[2.502964870068823,2.784102836263358],"z":[2.5151894616807247,2.5165674957743556],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"green","width":2},"mode":"lines","name":"yCamera 0","showlegend":false,"x":[2.483671569877341,2.6826377645536565],"y":[2.502964870068823,2.7057147858538992],"z":[2.5151894616807247,2.233578160371329],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"blue","width":2},"mode":"lines","name":"zCamera 0","showlegend":false,"x":[2.483671569877341,2.28504400786746],"y":[2.502964870068823,2.3033304150938734],"z":[2.5151894616807247,2.231124018522171],"type":"scatter3d"},{"legendgroup":"Frames","legendgrouptitle":{"text":"Frames"},"marker":{"opacity":0.8,"size":4},"mode":"markers","name":"Camera 1","showlegend":true,"x":[-2.5013463636420137],"y":[2.473446893462963],"z":[2.52830140595633],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"red","width":2},"mode":"lines","name":"xCamera 1","showlegend":false,"x":[-2.5013463636420137,-2.7828059421650932],"y":[2.473446893462963,2.1892278887904064],"z":[2.52830140595633,2.5280503271802526],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"green","width":2},"mode":"lines","name":"yCamera 1","showlegend":false,"x":[-2.5013463636420137,-2.70391978388849],"y":[2.473446893462963,2.6743012693314245],"z":[2.52830140595633,2.2479060973220104],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"blue","width":2},"mode":"lines","name":"zCamera 1","showlegend":false,"x":[-2.5013463636420137,-2.301986099127605],"y":[2.473446893462963,2.2762741847088557],"z":[2.52830140595633,2.243032396326274],"type":"scatter3d"},{"legendgroup":"Frames","legendgrouptitle":{"text":"Frames"},"marker":{"opacity":0.8,"size":4},"mode":"markers","name":"Camera 2","showlegend":true,"x":[-2.4721337211046372],"y":[-2.5326891460911924],"z":[2.4918945368205407],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"red","width":2},"mode":"lines","name":"xCamera 2","showlegend":false,"x":[-2.4721337211046372,-2.1873769953366757],"y":[-2.5326891460911924,-2.81359253922492],"z":[2.4918945368205407,2.489269492845942],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"green","width":2},"mode":"lines","name":"yCamera 2","showlegend":false,"x":[-2.4721337211046372,-2.671726751752156],"y":[-2.5326891460911924,-2.7323721808821504],"z":[2.4918945368205407,2.208540857236859],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"blue","width":2},"mode":"lines","name":"zCamera 2","showlegend":false,"x":[-2.4721337211046372,-2.2744566378429485],"y":[-2.5326891460911924,-2.3296621298036264],"z":[2.4918945368205407,2.2095759199875027],"type":"scatter3d"},{"legendgroup":"Frames","legendgrouptitle":{"text":"Frames"},"marker":{"opacity":0.8,"size":4},"mode":"markers","name":"Camera 3","showlegend":true,"x":[2.504627603219495],"y":[-2.5113851978974036],"z":[2.4751645491462733],"type":"scatter3d"},{"hoverinfo":"skip","line":{"color":"red","width":2},"mode":"lines","name":"xCamera 3","showlegend":false,"x":[2.504627603219495,2.7867675126597775],"y":[-2.5113851978974036,-2.2 ...

# %% [markdown]
# # Standard Capture
#
# With all calibration done, a standard capture routine can be requested for the arena's usual operation.
#
# ---

# %%
input('Press Enter key to start Standard Capture...')

# %%
# Capture specifications
blob_count = 1 # Number of expected markers
delay_time = 10.0 # In seconds
capture_time = 20.0 # In seconds
window = 3 # The minimum ammount of points for interpolating 
throughput = 20 # Triangulated scenes per second
step = 1 / throughput # Interpolation timestep

# Capture synchronizer
synchronizer = Synchronizer(blob_count, window, step, capture_time)

# Request capture (start simulation)
if not server.request_capture(delay_time, synchronizer):
    sys.exit() # Capture request failed!
# Out:
# [SERVER] Capture info sent
# [SERVER] Capture confirmed!
# [SERVER] Waiting for clients...
# 	Client 0 registered
# 	Client 1 registered
# 	Client 2 registered
# 	Client 3 registered
# [SERVER] All clients registered!

# %%
verbose = False

print('[SERVER] Waiting delay...')
time.sleep(delay_time)

timeout = 5 # In seconds
server.udp_socket.settimeout(timeout) # Set server timeout
print(f'[SERVER] Timeout set to {timeout} seconds\n')

triangulation = 0
sync_triangulated_markers = np.empty((server.clients[0].synchronizer.sync_PTS.size, blob_count, 3))
all_triangulated_markers = []

# Breaks in the timeout
while True: 
    # Wait for message - Event guided!
    try:
        message_bytes, address = server.udp_socket.recvfrom(server.buffer_size)

    except socket.timeout as err:
        print('\n[SERVER] Timed Out!')
        
        break # Close capture loop due to timeout
    
    # Check if client exists
    try:
        ID = server.client_addresses[address] # Client Identifier
    
    except:
        if verbose: print('> Client not recognized')

        continue # Jump to wait for the next message
    
    # Show sender
    if verbose: print(f'> Received message from Client {ID} ({address[0]}, {address[1]}):')

    # Decode message
    try:
        message = np.frombuffer(message_bytes, dtype=np.float32)

    except:
        if verbose: print('> Couldn\'t decode message')

        continue # Jump to wait for the next message

    # Empty message
    if not message.size:
        if verbose: print('\tEmpty message')

        continue # Jump to wait for the next message

    # The message is composed as:
    # [u, v, A] (for each blob detected) + [u_min, y_min, PTS, IID] 
    IID = message[-1] # Image Index
    PTS = message[-2] # Presentation Timestamp
    
    # Valid message must have (3 * blob_count + 4) total elements
    if message.size !=  3 * blob_count + 4: 
        if message.size == 4: 
            if verbose: print(f'\tNo blobs were detected - {PTS :.3f} s')

        else: 
            if verbose: 
                print(f'\tWrong blob count or corrupted message')
                print(f'Corrupted Message: {message}')

        continue # Jump to the next message

    # Extracting blob data (coordinates & area)
    blob_data = message[:-4].reshape(-1, 3) # All but last 4 elements

    # Extracting centroids
    blob_centroids = blob_data[:,:2] # Ignoring their area

    # Undistorting blobs centroids
    undistorted_blobs = client.camera.undistort_points(blob_centroids)          

    # Print blobs
    if verbose:
        print(f'\tDetected Blobs - {PTS :.3f} s')
        print('\t' + str(blob_data).replace('\n', '\n\t'))

    # Save data
    valid_data = client.synchronizer.add_data(undistorted_blobs, PTS)

    if verbose: 
        if valid_data:
            print('\tData Accepted!')
        else:
            print('\tData Refused!')

    # Check for available interpolated data
    available = []

    synchronizers = [c.synchronizer for c in server.clients]
    for ID, S in enumerate(synchronizers):
        # Is there interpolated data? Non-interpolated blobs are negative!
        if np.any(S.sync_blobs[triangulation] >= 0): 
            available.append(ID)

    # If at least two cameras have interpolated data, triangulate 
    if len(available) >= 2:
        # Get the first two available
        pair = available[:2]

        blob_pair = [synchronizers[pair[0]].sync_blobs[triangulation],
                     synchronizers[pair[1]].sync_blobs[triangulation]]
        
        triangulated_markers = server.multiple_view.triangulate_by_pair(pair, blob_pair)
        all_triangulated_markers.append(triangulated_markers)

        # Update last triangulation flag
        if triangulation < sync_triangulated_markers.shape[0] - 1:
            triangulation += 1

all_triangulated_markers = np.hstack(all_triangulated_markers)
# Out:
# [SERVER] Timeout set to 5 seconds
#
#
# [SERVER] Timed Out!

# %% [markdown]
# # Capture Profile
#
# ---

# %%
# Create the Scene Viewer
scene = Viewer3D(title='Capture Profile', 
                 size=10)

# Add camera frames to the scene
for ID, camera in enumerate(server.multiple_view.camera_models): 
    scene.add_frame(camera.pose, f'Camera {ID}', axis_size=0.4)

# Add new reference
scene.add_frame(np.eye(4), 'Reference', axis_size=0.4)

# Add triangulated markers to the scene
scene.add_points(all_triangulated_markers, f'Markers')

# Plot scene
scene.figure.show(renderer='notebook_connected')
